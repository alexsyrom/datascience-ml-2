# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tnrange, tqdm_notebook
import gc
import pandas_profiling

# %%
sns.set_context('talk')

# %%
import warnings
warnings.filterwarnings('ignore', message='Changing the shape of non-C contiguous array')

# %% [markdown]
# # Read the data

# %%
test = pd.read_csv('csv/ech_test.csv', sep=';', index_col='id')
train = pd.read_csv('csv/ech_apprentissage.csv', sep=';', index_col='id')
# Out:
# /home/alexey/anaconda3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Graphs

# %%
train.columns
# Out:
# Index(['annee_naissance', 'annee_permis', 'marque', 'puis_fiscale', 'anc_veh',
#        'codepostal', 'energie_veh', 'kmage_annuel', 'crm', 'profession',
#        'var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9',
#        'var10', 'var11', 'var12', 'var13', 'var14', 'var15', 'var16', 'var17',
#        'var18', 'var19', 'var20', 'var21', 'var22', 'prime_tot_ttc'],
#       dtype='object')

# %%
pandas_profiling.ProfileReport(train)
# Out:
#     <meta charset="UTF-8">
#
#     <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#
#
#     </style>
#
# <div class="container pandas-profiling">
#      <div class="row headerrow highlight">
#             <h1>Overview</h1>
#     </div>
#
#
#     <div class="row variablerow">
#         <div class="col-md-6 namecol">
#             <p class="h4">Dataset info</p>
#              <table class="stats" style="margin-left: 1em;" >
#                         <tbody><tr><th>Number of variables</th>
#                         <td>34</td></tr>
#                         <tr><th>Number of observations</th>
#                         <td>300000</td></tr>
#                         <tr><th>Total Missing (%)</th>
#                         <td>0.0%</td></tr>
#                         <tr><th>Total size in memory</th>
#                         <td>77.8 MiB</td></tr>
#                         <tr><th>Average record size in memory</th>
#                         <td>272.0 B</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-6 namecol">
#             <p class="h4">Variables types</p>
#              <table class="stats" style="margin-left: 1em;">
#                         <tbody><tr><th>Numeric</th>
#                         <td>22</td></tr>
#                         <tr><th>Categorical</th>
#                         <td>9</td></tr>
#                         <tr><th>Date</th>
#                         <td>0</td></tr>
#                         <tr><th>Text (Unique)</th>
#                         <td>0</td></tr>
#                         <tr><th>Rejected</th>
#                         <td>3</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-12" style="padding-left: 1em;">
#             <p class="h4">Warnings</p>
#             <ul class="list-unstyled"><li><code>anc_veh</code> has 64174 / 21.4% zeros</l><li><code>annee_permis</code> is highly correlated with <code>annee_naissance</code> (ρ = 0.99615) <span class="label label-primary">Rejected</span></l><li><code>codepostal</code> has a high cardinality: 23711 distinct values  <span class="label label-warning">Warning</span></l><li><code>marque</code> has a high cardinality: 155 distinct values  <span class="label label-warning">Warning</span></l><li><code>var10</code> has 6316 / 2.1% zeros</l><li><code>var11</code> is highly correlated with <code>anc_veh</code> (ρ = 0.99903) <span class="label label-primary">Rejected</span></l><li><code>var12</code> is highly correlated with <code>kmage_annuel</code> (ρ = 0.90827) <span class="label label-primary">Rejected</span></l><li><code>var15</code> has 107347 / 35.8% zeros</l><li><code>var19</code> has 210146 / 70.0% zeros</l><li><code>var2</code> has 5266 / 1.8% zeros</l><li><code>var20</code> has 137154 / 45.7% zeros</l><li><code>var21</code> has 26423 / 8.8% zeros</l><li><code>var22</code> has 112575 / 37.5% zeros</l><li><code>var4</code> has 139795 / 46.6% zeros</l></ul>
#         </div>
#      </div>
#
#
#     <div class="row headerrow highlight">
#             <h1>Variables</h1>
#     </div>
#
#     <div class="row variablerow">
#         <div class="col-md-3 namecol">
#             <p class="h4">anc_veh<br/><small>Numeric</small></p>
#         </div>
#
#         <div class="col-md-6">
#             <div class="row">
#                 <div class="col-sm-6">
#                     <table class="stats ">
#                         <tr><th>Distinct count</th>
#                         <td>44</td></tr>
#                         <tr><th>Unique (%)<

# %%
pandas_profiling.ProfileReport(test)
# Out:
#     <meta charset="UTF-8">
#
#     <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#
#
#     </style>
#
# <div class="container pandas-profiling">
#      <div class="row headerrow highlight">
#             <h1>Overview</h1>
#     </div>
#
#
#     <div class="row variablerow">
#         <div class="col-md-6 namecol">
#             <p class="h4">Dataset info</p>
#              <table class="stats" style="margin-left: 1em;" >
#                         <tbody><tr><th>Number of variables</th>
#                         <td>33</td></tr>
#                         <tr><th>Number of observations</th>
#                         <td>30000</td></tr>
#                         <tr><th>Total Missing (%)</th>
#                         <td>0.0%</td></tr>
#                         <tr><th>Total size in memory</th>
#                         <td>7.6 MiB</td></tr>
#                         <tr><th>Average record size in memory</th>
#                         <td>264.0 B</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-6 namecol">
#             <p class="h4">Variables types</p>
#              <table class="stats" style="margin-left: 1em;">
#                         <tbody><tr><th>Numeric</th>
#                         <td>22</td></tr>
#                         <tr><th>Categorical</th>
#                         <td>7</td></tr>
#                         <tr><th>Date</th>
#                         <td>0</td></tr>
#                         <tr><th>Text (Unique)</th>
#                         <td>0</td></tr>
#                         <tr><th>Rejected</th>
#                         <td>4</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-12" style="padding-left: 1em;">
#             <p class="h4">Warnings</p>
#             <ul class="list-unstyled"><li><code>anc_veh</code> has 6156 / 20.5% zeros</l><li><code>annee_permis</code> is highly correlated with <code>annee_naissance</code> (ρ = 0.9961) <span class="label label-primary">Rejected</span></l><li><code>marque</code> has a high cardinality: 74 distinct values  <span class="label label-warning">Warning</span></l><li><code>var10</code> has 732 / 2.4% zeros</l><li><code>var11</code> is highly correlated with <code>anc_veh</code> (ρ = 0.9987) <span class="label label-primary">Rejected</span></l><li><code>var12</code> is highly correlated with <code>kmage_annuel</code> (ρ = 0.9154) <span class="label label-primary">Rejected</span></l><li><code>var14</code> has constant value N <span class="label label-primary">Rejected</span></l><li><code>var15</code> has 8881 / 29.6% zeros</l><li><code>var19</code> has 20318 / 67.7% zeros</l><li><code>var20</code> has 17552 / 58.5% zeros</l><li><code>var21</code> has 4498 / 15.0% zeros</l><li><code>var22</code> has 14115 / 47.0% zeros</l><li><code>var4</code> has 13901 / 46.3% zeros</l></ul>
#         </div>
#      </div>
#
#
#     <div class="row headerrow highlight">
#             <h1>Variables</h1>
#     </div>
#
#     <div class="row variablerow">
#         <div class="col-md-3 namecol">
#             <p class="h4">anc_veh<br/><small>Numeric</small></p>
#         </div>
#
#         <div class="col-md-6">
#             <div class="row">
#                 <div class="col-sm-6">
#                     <table class="stats ">
#                         <tr><th>Distinct count</th>
#                         <td>44</td></tr>
#                         <tr><th>Unique (%)</th>
#                         <td>0.1%</td></tr>
#                         <tr class="ignore">

# %% [markdown]
# var14 оставим, но можно больше внимания уделять значению N

# %%
set(train['codepostal'][train['codepostal'].apply(lambda x: not str(x).isdigit())])
# Out:
# {'ARMEE', 'NR'}

# %% [markdown]
# Исследования показали, что NR есть пропуск

# %% [markdown]
# Выкинем лишние признаки, которые уже сильно скоррелированы

# %%
drop_cols = ['annee_permis', 'var11', 'var12']

# %%
train = train.drop(drop_cols, axis=1)

# %%
test = test.drop(drop_cols, axis=1)

# %% [markdown]
# Заменим NR на NaN

# %%
train.replace('NR', np.NaN, inplace=True)
test.replace('NR', np.NaN, inplace=True)

# %% [markdown]
# Заменим ARMEE в codepostal на -1

# %%
train.loc[train.codepostal == 'ARMEE', 'codepostal'] = '-1'

# %%
train.loc[train.codepostal == '-1', 'codepostal']
# Out:
# id
# 46294    -1
# 46295    -1
# 46296    -1
# Name: codepostal, dtype: object

# %%
test.codepostal.dtype
# Out:
# dtype('int64')

# %% [markdown]
# В тесте нет ARMEE и пропусков.

# %% [markdown]
# Переведём codepostal в числа

# %%
train.codepostal = pd.to_numeric(train.codepostal)

# %% [markdown]
# Опять посмотрим на отчёт

# %%
pandas_profiling.ProfileReport(train, threshold=1.1)
# Out:
#     <meta charset="UTF-8">
#
#     <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#
#
#     </style>
#
# <div class="container pandas-profiling">
#      <div class="row headerrow highlight">
#             <h1>Overview</h1>
#     </div>
#
#
#     <div class="row variablerow">
#         <div class="col-md-6 namecol">
#             <p class="h4">Dataset info</p>
#              <table class="stats" style="margin-left: 1em;" >
#                         <tbody><tr><th>Number of variables</th>
#                         <td>31</td></tr>
#                         <tr><th>Number of observations</th>
#                         <td>300000</td></tr>
#                         <tr><th>Total Missing (%)</th>
#                         <td>0.0%</td></tr>
#                         <tr><th>Total size in memory</th>
#                         <td>71.0 MiB</td></tr>
#                         <tr><th>Average record size in memory</th>
#                         <td>248.0 B</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-6 namecol">
#             <p class="h4">Variables types</p>
#              <table class="stats" style="margin-left: 1em;">
#                         <tbody><tr><th>Numeric</th>
#                         <td>22</td></tr>
#                         <tr><th>Categorical</th>
#                         <td>8</td></tr>
#                         <tr><th>Date</th>
#                         <td>0</td></tr>
#                         <tr><th>Text (Unique)</th>
#                         <td>0</td></tr>
#                         <tr><th>Rejected</th>
#                         <td>1</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-12" style="padding-left: 1em;">
#             <p class="h4">Warnings</p>
#             <ul class="list-unstyled"><li><code>anc_veh</code> has 64174 / 21.4% zeros</l><li><code>codepostal</code> is highly correlated with <code>id</code> (ρ = 0.9973) <span class="label label-primary">Rejected</span></l><li><code>marque</code> has a high cardinality: 155 distinct values  <span class="label label-warning">Warning</span></l><li><code>var10</code> has 6316 / 2.1% zeros</l><li><code>var15</code> has 107347 / 35.8% zeros</l><li><code>var19</code> has 210146 / 70.0% zeros</l><li><code>var2</code> has 5266 / 1.8% zeros</l><li><code>var20</code> has 137154 / 45.7% zeros</l><li><code>var21</code> has 26423 / 8.8% zeros</l><li><code>var22</code> has 112575 / 37.5% zeros</l><li><code>var4</code> has 139795 / 46.6% zeros</l></ul>
#         </div>
#      </div>
#
#
#     <div class="row headerrow highlight">
#             <h1>Variables</h1>
#     </div>
#
#     <div class="row variablerow">
#         <div class="col-md-3 namecol">
#             <p class="h4">anc_veh<br/><small>Numeric</small></p>
#         </div>
#
#         <div class="col-md-6">
#             <div class="row">
#                 <div class="col-sm-6">
#                     <table class="stats ">
#                         <tr><th>Distinct count</th>
#                         <td>44</td></tr>
#                         <tr><th>Unique (%)</th>
#                         <td>0.0%</td></tr>
#                         <tr class="ignore"><th>Missing (%)</th>
#                         <td>0.0%</td></tr>
#                         <tr class="ignore"><th>Missing (n)</th>
#                         <td>0</td></tr>
#                         <tr class="ignore"><th>Infinite (%)</th>
#                         <td>0.0%</td></tr>
#                         <tr class="ignore"><th>Infinite

# %% [markdown]
# Id и codepostal сильно коррелированы, id присваивались по мере роста codepostal. Codepostal оставим, по нему будем делить на фолды

# %%
train.loc[train.codepostal == -1, 'codepostal']
# Out:
# id
# 46294   -1.0
# 46295   -1.0
# 46296   -1.0
# Name: codepostal, dtype: float64

# %%
train.iloc[46296]['codepostal']
# Out:
# 13047.0

# %%
train.iloc[46292]['codepostal']
# Out:
# 13001.0

# %% [markdown]
# Заменим -1 на 13024, как на среднее арифметическое

# %%
train.loc[train.codepostal == -1, 'codepostal'] = 13024

# %%
train_corr = train.corr()
test_corr = test.corr()

# %%
sns.heatmap(train_corr)

# %% [markdown]
# Выкинем var1

# %%
train = train.drop('var1', axis=1)

# %%
test = test.drop('var1', axis=1)

# %%
train.columns
# Out:
# Index(['annee_naissance', 'marque', 'puis_fiscale', 'anc_veh', 'codepostal',
#        'energie_veh', 'kmage_annuel', 'crm', 'profession', 'var2', 'var3',
#        'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10', 'var13',
#        'var14', 'var15', 'var16', 'var17', 'var18', 'var19', 'var20', 'var21',
#        'var22', 'prime_tot_ttc'],
#       dtype='object')

# %% [markdown]
# Пропуски заменим при рассмотрении конкретных моделей. Так как пропусков не много, то не будем создавать лишние признаки (по крайней мере не здесь)

# %% [markdown]
# # Target label separation

# %%
y_train = train['prime_tot_ttc']
train = train.drop('prime_tot_ttc', axis=1)

# %% [markdown]
# # Save to file

# %%
y_train.to_csv('preprocessed_csv/y_train.csv', sep=';')

# %%
train.to_csv('preprocessed_csv/train.csv', sep=';')

# %%
test.to_csv('preprocessed_csv/test.csv', sep=';')
